# %%
# !pip install  -q pyngrok
# !pip install  -q "unstructured[all-docs]"
# !pip install  -q langchain
# !pip install  -q sentence-transformers
# !pip install  -q rank-bm25
# !pip install  -q langchain_community
# !pip install  -q langchain_huggingface
# !pip install  -q sentence_transformers
# !pip install  -q faiss-cpu
# !pip install  -q fastapi
# !pip install  -q uvicorn
# !pip install  -q pydantic>=2
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 16.5 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 80.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 19.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 31.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.5/112.5 kB 10.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.7/48.7 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 99.0 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 58.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 79.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.6/167.6 kB 9.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 87.5 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 72.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.8/207.8 kB 18.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.8/160.8 kB 14.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.0/322.0 kB 16.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.8 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 85.0 MB/s eta 0:00:00:00:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 62.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 2.0 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 9.4 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.4 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.2 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 72.8 MB/s eta 0:00:00:00:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 kB 15.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 86.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 105.0 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.3 MB/s eta 0:00:00
#   Building wheel for langdetect (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.8.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-cloud-automl 1.0.1 requires google-api-core[grpc]<2.0.0dev,>=1.14.0, but you have google-api-core 2.25.1 which is incompatible.
# google-cloud-translate 3.12.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 6.32.1 which is incompatible.
# ypy-websocket 0.8.4 requires aiofiles<23,>=22.1.0, but you have aiofiles 24.1.0 which is incompatible.
# google-ai-generativelanguage 0.6.15 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 6.32.1 which is incompatible.
# tensorflow 2.18.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 6.32.1 which is incompatible.
# bigframes 2.8.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.31.0, but you have google-cloud-bigquery 3.25.0 which is incompatible.
# bigframes 2.8.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 2.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.8.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# datasets 3.6.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2025.5.1 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# tensorflow 2.18.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 6.32.1 which is incompatible.
# bigframes 2.8.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.31.0, but you have google-cloud-bigquery 3.25.0 which is incompatible.
# bigframes 2.8.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 29.9 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 52.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.5/447.5 kB 26.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 5.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.8.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-cloud-automl 1.0.1 requires google-api-core[grpc]<2.0.0dev,>=1.14.0, but you have google-api-core 2.25.1 which is incompatible.
# datasets 3.6.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2025.5.1 which is incompatible.
# google-cloud-translate 3.12.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 6.32.1 which is incompatible.
# google-colab 1.0.0 requires google-auth==2.38.0, but you have google-auth 2.40.3 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.1 which is incompatible.
# google-ai-generativelanguage 0.6.15 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 6.32.1 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.5.1 which is incompatible.
# tensorflow 2.18.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 6.32.1 which is incompatible.
# bigframes 2.8.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.31.0, but you have google-cloud-bigquery 3.25.0 which is incompatible.
# bigframes 2.8.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# jupyter-kernel-gateway 2.5.2 requires jupyter-client<8.0,>=5.2.0, but you have jupyter-client 8.6.3 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 563.3/563.3 kB 11.3 MB/s eta 0:00:00a 0:00:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 3.6.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2025.5.1 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 59.6 MB/s eta 0:00:00:00:0100:01

# %%
# %%writefile BACKEND2.py

import google.generativeai
import os
import json
import re
from kaggle_secrets import UserSecretsClient
from fastapi import FastAPI, UploadFile, Form
from pydantic import BaseModel, Field
import time
from typing import List, Dict, Any
from fastapi.middleware.cors import CORSMiddleware

user_secrets = UserSecretsClient()
secret_value_0 = user_secrets.get_secret("GOOGLE_API_KEY")
google.generativeai.configure(api_key=secret_value_0)

system_message = """
You are a specialized legal advisory assistant operating strictly under the Indian legal framework.  
Your task is to analyze ONLY the case provided by the user and produce a structured, court-style legal advisory.  

CRITICAL: You must respond with ONLY a valid JSON object. No markdown, no explanations, no extra text.

Required JSON structure:
{
  "title": "Brief case title or Legal Advisory to [Client Name]",
  "petitioner": "Name of the petitioner",
  "respondent": "Name of the respondent",
  "successProbability": "X%" (only percentage, e.g., "75%"),
  "likelyOutcome": "Detailed prediction of probable result with legal reasoning",
  "strongPoints": "List of petitioner's strongest legal and factual arguments",
  "weakPoints": "List of petitioner's weakest or most vulnerable arguments", 
  "legalPrecedents": "List of 5 relevant Indian cases with citations and brief explanations",
  "strategies": "Possible remedies and compliance steps if petitioner loses",
  "penalties": "Potential penalties and liabilities under relevant Indian statutes",
  "finalAdvisory": "Realistic legal feedback combining all factors and probable outcome implications"
}

Analysis Guidelines:
- Identify Petitioner(s) and Respondent(s) clearly
- Predict probable case result with legal reasoning
- Assign percentage (0-100%) for petitioner's success chance
- List 5 directly relevant Indian cases with citations
- Explain strongest and weakest arguments under Indian law
- Provide comprehensive final advisory with remedies and penalties

Legal Framework:
- Prioritize Indian Constitution, statutes, and Supreme Court/High Court judgments
- Apply proportionality test, fundamental rights, and statutory compliance
- Use legally precise, court-advisory tone
- Ensure reasoning is consistent with Indian legal environment
- Include only directly relevant precedents, not generic cases

IMPORTANT: Return ONLY the JSON object. No extra text, markdown, or explanations outside the JSON.
"""

gemini = google.generativeai.GenerativeModel(
    model_name="gemini-2.5-flash",
    system_instruction=system_message
)

def extract_json_from_response(response_text: str) -> dict:
    """Extract and parse JSON from Gemini response, handling various formats"""
    try:
        # Clean the response
        cleaned = response_text.strip()
        
        # Remove markdown code blocks if present
        if '```' in cleaned:
            # Extract content between code blocks
            json_match = re.search(r'```(?:json)?\s*(\{.*?\})\s*```', cleaned, re.DOTALL)
            if json_match:
                cleaned = json_match.group(1)
        
        # Find JSON object in the text
        json_match = re.search(r'\{.*\}', cleaned, re.DOTALL)
        if json_match:
            json_str = json_match.group(0)
            return json.loads(json_str)
        
        # If no JSON found, try parsing the entire response
        return json.loads(cleaned)
        
    except json.JSONDecodeError as e:
        print(f"JSON parsing error: {e}")
        print(f"Response text: {response_text}")
        # Return fallback structure
        return {
            "title": "Legal Case Analysis",
            "petitioner": "Not specified",
            "respondent": "Not specified", 
            "successProbability": "Not specified",
            "likelyOutcome": "Analysis could not be parsed. Raw response: " + response_text,
            "strongPoints": "Please check raw response",
            "weakPoints": "Please check raw response",
            "legalPrecedents": "Please check raw response",
            "strategies": "Please check raw response", 
            "penalties": "Please check raw response",
            "finalAdvisory": "JSON parsing failed. Please try again."
        }

def answer(question: str) -> dict:
    """Get structured legal analysis from Gemini"""
    try:
        user_msg = "Analyze this case and provide structured JSON response: " + question
        response = gemini.generate_content(user_msg)
        
        print(f"Raw Gemini response: {response.text}")  # Debug logging
        
        # Extract and parse JSON
        parsed_response = extract_json_from_response(response.text)
        
        # Validate required fields
        required_fields = ["title", "petitioner", "respondent", "successProbability", 
                          "likelyOutcome", "strongPoints", "weakPoints", "legalPrecedents",
                          "strategies", "penalties", "finalAdvisory"]
        
        for field in required_fields:
            if field not in parsed_response:
                parsed_response[field] = "Not provided"
        
        return parsed_response
        
    except Exception as e:
        print(f"Error in answer function: {e}")
        return {
            "title": "Error in Analysis",
            "petitioner": "Error",
            "respondent": "Error",
            "successProbability": "Error",
            "likelyOutcome": f"Error occurred: {str(e)}",
            "strongPoints": "Error in processing",
            "weakPoints": "Error in processing",
            "legalPrecedents": "Error in processing",
            "strategies": "Error in processing",
            "penalties": "Error in processing", 
            "finalAdvisory": "Please try again"
        }

app = FastAPI()
app.add_middleware(
    CORSMiddleware,
    allow_origins=["*"],
    allow_credentials=True,
    allow_methods=["*"],
    allow_headers=["*"],
)

# Updated response model for JSON objects
class SubmissionResponse(BaseModel):
    answers: List[Dict[str, Any]] = Field(...)  # Changed to Dict for JSON objects

class SubmissionRequest(BaseModel):
    questions: List[str] = Field(...)

@app.get("/")
def read_root():
    return {"Status of case outcome prediction": "API is running."}

@app.post("/caseoutcomeprediction", response_model=SubmissionResponse)
def caseoutcomeprediction(request: SubmissionRequest):
    print("New Request Received")
    start_time = time.time()
    answers = []
    
    for question in request.questions:
        response = answer(question)  # This now returns a dict
        answers.append(response)
        
    print("Generated answers.")
    total_time = time.time() - start_time
    print(f"Request was processed in {total_time:.2f} seconds.")
    
    return SubmissionResponse(answers=answers)
# Out:
# Writing BACKEND2.py

# %%
from pyngrok import ngrok
# !ngrok config add-authtoken 32tBPN0LJscI4hVwmdpFsgRCGpD_6XU5NeYodcCerxKiy1tw5
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
import nest_asyncio
import uvicorn
from pyngrok import ngrok
nest_asyncio.apply()
ngrok.kill()
public_url=ngrok.connect(addr="8001",proto="http",hostname="stylish-onie-slung.ngrok-free.app")
print(public_url)
uvicorn.run("BACKEND2:app", host="0.0.0.0", port=8001, reload=True)
# Out:
# INFO:     Will watch for changes in these directories: ['/kaggle/working']
# INFO:     Uvicorn running on http://0.0.0.0:8001 (Press CTRL+C to quit)
# INFO:     Started reloader process [36] using StatReload
# NgrokTunnel: "https://stylish-onie-slung.ngrok-free.app" -> "http://localhost:8001"
# INFO:     Started server process [206]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     103.132.31.50:0 - "GET / HTTP/1.1" 200 OK
# INFO:     103.132.31.50:0 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# INFO:     103.132.31.50:0 - "GET /docs HTTP/1.1" 200 OK
# INFO:     103.132.31.50:0 - "GET /openapi.json HTTP/1.1" 200 OK
# INFO:     103.132.31.50:0 - "OPTIONS /caseoutcomeprediction HTTP/1.1" 200 OK
# New Request Received
# Raw Gemini response: ```json
# {
#   "title": "Legal Advisory to ABC Technologies Pvt. Ltd.",
#   "petitioner": "ABC Technologies Pvt. Ltd.",
#   "respondent": "State of Maharashtra",
#   "successProbability": "50%",
#   "likelyOutcome": "The Bombay High Court is likely to acknowledge the State's legitimate interest in regulating AI models trained on sensitive public data, especially concerning privacy, misinformation, and public safety, upholding its power under Article 19(6) of the Constitution of India. However, if ABC Technologies can effectively substantiate its claims of an opaque, arbitrary, or politically influenced licensing process, the Court may strike down or direct modifications to the specific provisions of the Maharashtra Artificial Intelligence Regulation Act, 2024, that pertain to the licensing mechanism, ensuring transparency, objectivity, and adherence to principles of natural justice and proportionality. A complete nullification of the entire Act is less probable.",
#   "strongPoints": [
#     "Challenge based on Article 19(1)(g) if the restrictions imposed are found to be unreasonable, excessive, or not in public interest, particularly if they stifle innovation and competition.",
#     "Arguments under Article 301 if the regulations are proven to create an unreasonable and disproportionate barrier to trade and commerce within India, beyond being merely regulatory or compensatory.",
#     "The assertion that the licensing process is 'opaque, politically influenced,' and could 'stifle competition' is a strong ground if substantial evidence can be produced to demonstrate arbitrariness, lack of clear criteria, or bias, thus violating Article 14 (Equality before Law) read with Article 19(1)(g).",
#     "Potential for the Act to be challenged on grounds of lack of 'intelligible differentia' and 'rational nexus' to the object sought to be achieved, if the provisions are too broad or vague."
#   ],
#   "weakPoints": [
#     "The State's argument for regulation as a 'reasonable restriction' under Article 19(6) for public interest (privacy, misinformation, public safety) is a potent legal ground, especially given the evolving nature and potential risks of AI.",
#     "High burden of proof on ABC Technologies to definitively establish 'political influence' and 'opaqueness' with concrete evidence rather than mere allegations.",
#     "The Court may apply the proportionality test, and if the State can demonstrate that the restrictions are proportionate to the legitimate aim of protecting public interest and sensitive data, ABC Technologies' challenge will weaken.",
#     "Difficulty in challenging the State's legislative competence to regulate a sector that has wide-ranging societal impacts, especially if the Act is framed to serve public policy objectives."
#   ],
#   "legalPrecedents": [
#     {
#       "case": "Chintaman Rao v. State of M.P., AIR 1951 SC 118",
#       "citation": "AIR 1951 SC 118",
#       "explanation": "This case laid down that 'reasonable restrictions' under Article 19(6) must not be arbitrary or excessive, and must have a reasonable relation to the object which the legislation seeks to achieve."
#     },
#     {
#       "case": "O.K.N. Engineering Works v. Union of India, (1974) 4 SCC 275",
#       "citation": "(1974) 4 SCC 275",
#       "explanation": "Reiterated that the test of reasonableness of restrictions on fundamental rights should be objective and depend on the circumstances and the nature of the right infringed."
#     },
#     {
#       "case": "Automobile Transport (Rajasthan) Ltd. v. State of Rajasthan, AIR 1962 SC 1406",
#       "citation": "AIR 1962 SC 1406",
#       "explanation": "Distinguished between regulatory/compensatory taxes/fees and restrictive measures, holding that Article 301 prohibits only those restrictions that directly and immediately impede trade, commerce, and intercourse, not incidental or regulatory measures."
#     },
#     {
#       "case": "E.P. Royappa v. State of Tamil Nadu, AIR 1974 SC 555",
#       "citation": "AIR 1974 SC 555",
#       "explanation": "Established that arbitrariness is the antithesis of equality, and any state action that is arbitrary would violate Article 14 of the Constitution. This can be used to challenge an opaque and arbitrary licensing process."
#     },
#     {
#       "case": "Shreya Singhal v. Union of India, (2015) 5 SCC 1",
#       "citation": "(2015) 5 SCC 1",
#       "explanation": "While primarily dealing with freedom of speech on the internet, this case extensively discussed the concept of 'reasonable restrictions,' proportionality, and the need for clear, narrowly tailored legislation when impinging on fundamental rights in the digital domain."
#     }
#   ],
#   "strategies": [
#     "Focus the challenge primarily on the 'procedural' aspects of the Act related to licensing (opaqueness, discretion, lack of objective criteria) rather than entirely on the State's 'power' to regulate AI.",
#     "Gather robust documentary and testimonial evidence to demonstrate the arbitrariness, lack of transparency, and potential for political influence in the specified licensing process.",
#     "Propose a detailed alternative framework for licensing that ensures transparency, objectivity, and due process, demonstrating a cooperative approach while protecting business interests.",
#     "Highlight the potential negative economic impact of the current Act on innovation, investment, and competition within the AI sector in Maharashtra.",
#     "Seek interim relief from the Bombay High Court to permit continued operation under certain conditions until the final adjudication of the matter."
#   ],
#   "penalties": [
#     "Imposition of fines as stipulated under the Maharashtra Artificial Intelligence Regulation Act, 2024, for non-compliance with licensing requirements.",
#     "Suspension or revocation of the license to operate or deploy AI models trained on sensitive public data.",
#     "Orders to cease and desist from further operations or deployment of non-compliant AI models.",
#     "Potential for civil liabilities and injunctions if non-compliant AI operations cause harm or breach privacy.",
#     "Significant reputational damage and loss of trust from clients, investors, and the public.",
#     "Increased legal and compliance costs for defending against enforcement actions."
#   ],
#   "finalAdvisory": "ABC Technologies Pvt. Ltd. faces a challenging, but not insurmountable, legal battle. While the State of Maharashtra has a strong legal basis to regulate emerging technologies like AI for public safety and data privacy under the 'reasonable restriction' clause of Article 19(6), the company's strongest avenue of challenge lies in proving that the *manner* of regulation, specifically the licensing process, is arbitrary, opaque, and disproportionate, thereby violating fundamental rights under Articles 14 and 19(1)(g). It is crucial to collect concrete evidence of procedural infirmities and potential for misuse. A complete striking down of the entire Act is unlikely. The more realistic and advisable strategy is to seek judicial directives for the modification of the Act's provisions to ensure transparency, objectivity, and due process in the licensing framework. The focus should be on ensuring that the regulations are truly 'reasonable' and 'proportionate' to the stated public interest objectives, rather than being instruments that stifle legitimate trade and innovation. Non-compliance, if the challenge fails, could lead to significant financial penalties, operational shutdowns, and severe reputational damage."
# }
# ```
# Generated answers.
# Request was processed in 26.12 seconds.
# INFO:     103.132.31.50:0 - "POST /caseoutcomeprediction HTTP/1.1" 200 OK
# INFO:     103.132.31.50:0 - "OPTIONS /caseoutcomeprediction HTTP/1.1" 200 OK
# New Request Received
# Raw Gemini response: ```json
# {
#   "title": "Legal Advisory to ABC Technologies Pvt. Ltd. regarding Maharashtra AI Regulation Act, 2024",
#   "petitioner": "ABC Technologies Pvt. Ltd.",
#   "respondent": "State of Maharashtra",
#   "successProbability": "45%",
#   "likelyOutcome": "The Bombay High Court is likely to uphold the Maharashtra Artificial Intelligence Regulation Act, 2024, in principle, recognizing the State's legitimate interest in regulating AI models trained on sensitive public data for privacy and public safety. However, the Court may direct the State to issue clearer, more transparent guidelines for the licensing process to mitigate concerns of opaqueness and potential for stifling competition, particularly if ABC Technologies can present compelling evidence of arbitrariness or lack of due process in the current framework. There is a moderate chance that specific provisions found to be arbitrary or unduly restrictive without clear public interest justification might be struck down or read down to ensure proportionality.",
#   "strongPoints": [
#     "The argument that an opaque and potentially politically influenced licensing process violates Article 19(1)(g) by imposing unreasonable restrictions on the freedom to practice trade or business.",
#     "The claim that the Act, if implemented arbitrarily, could stifle competition and create an unfair trade environment, potentially infringing Article 301.",
#     "The absence of clear, objective criteria in the licensing process, if proven, would be a strong ground to challenge its reasonableness and non-arbitrariness, a cornerstone of Indian administrative law.",
#     "The principle of proportionality: if the restrictions imposed by the Act are found to be excessive or not narrowly tailored to achieve the stated public interest goals, they could be challenged."
#   ],
#   "weakPoints": [
#     "The State's strong public interest argument under Article 19(6) regarding risks to privacy, misinformation, and public safety posed by AI trained on sensitive data. Courts generally grant latitude to the legislature when regulating emerging technologies in the public interest.",
#     "The burden of proof lies with ABC Technologies to demonstrate that the licensing process is indeed 'opaque, politically influenced, and used to stifle competition' rather than being a necessary regulatory measure.",
#     "Judicial deference to legislative wisdom in policy matters, especially in nascent regulatory fields like AI, where the State's objective is to protect citizens.",
#     "The global trend towards regulating AI, which might lead courts to uphold such legislation if it meets the basic tests of reasonableness and non-arbitrariness."
#   ],
#   "legalPrecedents": [
#     {
#       "case": "Chintaman Rao v. State of Madhya Pradesh, AIR 1951 SC 118",
#       "citation": "AIR 1951 SC 118",
#       "explanation": "Established that a law imposing restrictions on fundamental rights must be reasonable, both procedurally and substantively. This case would support ABC's argument if the licensing process is deemed unreasonable."
#     },
#     {
#       "case": "Om Prakash v. State of U.P., AIR 1955 SC 104",
#       "citation": "AIR 1955 SC 104",
#       "explanation": "Reiterated that restrictions on the freedom to carry on trade must be reasonable and in the public interest, emphasizing the need for a balance between individual liberty and societal welfare."
#     },
#     {
#       "case": "Mohammad Hanif Qureshi v. State of Bihar, AIR 1958 SC 731",
#       "citation": "AIR 1958 SC 731",
#       "explanation": "Laid down factors to determine the reasonableness of restrictions, including the nature of the right infringed, the purpose of the restriction, the extent and urgency of the evil sought to be remedied, and the proportionality of the restriction to the mischief."
#     },
#     {
#       "case": "Modern Dental College and Research Centre v. State of Madhya Pradesh, (2016) 7 SCC 353",
#       "citation": "(2016) 7 SCC 353",
#       "explanation": "Provided a comprehensive framework for the proportionality test under Article 19(6), requiring a legitimate goal, rational connection, necessity, and balancing of infringement with the benefit."
#     },
#     {
#       "case": "Shreya Singhal v. Union of India, (2015) 5 SCC 1",
#       "citation": "(2015) 5 SCC 1",
#       "explanation": "Though primarily about free speech, this case's analysis on vagueness, overbreadth, and proportionality of restrictions on fundamental rights is highly relevant for challenging the 'opaqueness' and potential 'stifling competition' aspects of the AI Regulation Act."
#     }
#   ],
#   "strategies": [
#     "Gather concrete evidence to substantiate claims of opaqueness, political influence, and how the current licensing process disproportionately stifles competition for ABC Technologies.",
#     "Focus arguments on the lack of clear guidelines, subjective decision-making, and arbitrary application of the Act, rather than challenging the State's broad power to regulate AI.",
#     "If the Act is upheld, comply fully with the licensing requirements while simultaneously advocating for transparent rules and objective criteria through representations to the State government and relevant regulatory bodies.",
#     "Explore potential amendments to the Act or the issuance of detailed rules thereunder by engaging with industry associations and stakeholders to push for a more equitable and predictable regulatory environment.",
#     "Consider training AI models on non-sensitive data where possible to reduce regulatory burden, if commercially viable."
#   ],
#   "penalties": [
#     "Prohibition from operating or deploying AI models trained on sensitive public data within Maharashtra.",
#     "Significant monetary fines for non-compliance, which could be recurring.",
#     "Potential revocation of existing business licenses or inability to obtain new ones, impacting overall business operations.",
#     "Reputational damage and loss of trust from clients and the public due to regulatory non-compliance.",
#     "Possible legal actions by individuals whose data privacy is compromised due to unregulated AI operations, even if not directly covered by the Act's penalties."
#   ],
#   "finalAdvisory": "ABC Technologies Pvt. Ltd. faces a challenging, yet not insurmountable, legal battle. While the State of Maharashtra has a strong public interest argument for regulating AI, especially concerning sensitive public data, the claims of an opaque and potentially arbitrary licensing process are critical. The success probability is moderate, contingent largely on the ability to present concrete evidence demonstrating how the Act's implementation violates the principles of reasonableness and non-arbitrariness under Articles 19(1)(g) and 301. The likely outcome suggests the Act might be upheld in principle, but with judicial directives for greater transparency and clearer guidelines in its implementation. It is crucial for ABC Technologies to meticulously document instances of procedural irregularities and arbitrary decisions. Should the challenge prove unsuccessful, immediate compliance with the regulatory framework, coupled with proactive engagement with the State for refining the guidelines, will be essential to mitigate potential penalties and ensure business continuity. Preparations for both winning and losing scenarios are advisable."
# }
# ```
# Generated answers.
# Request was processed in 30.60 seconds.
# INFO:     103.132.31.50:0 - "POST /caseoutcomeprediction HTTP/1.1" 200 OK
# INFO:     103.132.31.50:0 - "OPTIONS /caseoutcomeprediction HTTP/1.1" 200 OK
# New Request Received
# Raw Gemini response: ```json
# {
#   "title": "Legal Advisory to ABC Technologies Pvt. Ltd.",
#   "petitioner": "ABC Technologies Pvt. Ltd.",
#   "respondent": "State of Maharashtra",
#   "successProbability": "40%",
#   "likelyOutcome": "The Bombay High Court is likely to consider the State's arguments regarding public safety, privacy, and misinformation as valid grounds for imposing regulations on AI models trained on sensitive public data. While the Court may acknowledge the petitioner's rights under Article 19(1)(g) and Article 301, it is unlikely to strike down the entire Maharashtra Artificial Intelligence Regulation Act, 2024. The Court might, however, scrutinize the 'reasonableness' and 'proportionality' of the licensing process. If ABC Technologies can sufficiently prove the opacity and political influence in the licensing, the Court may direct the State to formulate clearer, transparent, and objective guidelines for the licensing process, rather than nullifying the entire legislation. A complete invalidation of the Act is less probable, given the legitimate public interest concerns raised by the State.",
#   "strongPoints": [
#     "Challenge based on Article 19(1)(g) – fundamental right to practice trade/business, asserting the restriction is not 'reasonable'.",
#     "Challenge based on Article 301 – freedom of trade, commerce, and intercourse, arguing the law impedes free market operations.",
#     "Allegations of an 'opaque' and 'politically influenced' licensing process, which, if substantiated with evidence, could be deemed arbitrary and violative of equality and fairness principles.",
#     "Potential for the law to 'stifle competition' and create barriers to entry for AI companies, impacting the innovative ecosystem."
#   ],
#   "weakPoints": [
#     "High burden on the petitioner to demonstrate that the state legislation is *not* a reasonable restriction under Article 19(6) in the interest of the general public.",
#     "The State's arguments regarding risks to privacy, misinformation, and public safety from AI models trained on sensitive public data are strong and legitimate public interest concerns, likely to be viewed favorably by the court.",
#     "Lack of specific evidence provided in the facts to substantiate claims of 'opacity' and 'political influence'; such claims require robust evidentiary support.",
#     "Courts generally exhibit judicial restraint in striking down legislative enactments, requiring them to be manifestly arbitrary or unconstitutional beyond doubt."
#   ],
#   "legalPrecedents": [
#     {
#       "case": "Chintaman Rao v. The State of Madhya Pradesh, AIR 1951 SC 118",
#       "citation": "AIR 1951 SC 118",
#       "explanation": "Established that a restriction on fundamental rights must be 'reasonable' and must bear a rational relation to the object which the legislature seeks to achieve. A restriction which is 'arbitrary' or 'excessive' will not be reasonable."
#     },
#     {
#       "case": "State of Madras v. V.G. Row, AIR 1952 SC 196",
#       "citation": "AIR 1952 SC 196",
#       "explanation": "Laid down the test for determining the 'reasonableness' of restrictions on fundamental rights, stating that both the substantive and procedural aspects of the restriction must be examined and that the restrictions should not be 'arbitrary' or 'excessive'."
#     },
#     {
#       "case": "Saghir Ahmad v. State of U.P., AIR 1954 SC 728",
#       "citation": "AIR 1954 SC 728",
#       "explanation": "Dealt with the freedom of trade and commerce under Article 301 and the scope of permissible state regulation, holding that while the state can regulate, it cannot create monopolies without due process or valid public interest grounds."
#     },
#     {
#       "case": "Om Prakash v. Union of India, (2004) 6 SCC 325",
#       "citation": "(2004) 6 SCC 325",
#       "explanation": "Reiterated the principles of 'reasonable restriction' and 'proportionality', emphasizing that restrictions must be necessary and proportionate to the legitimate aim sought to be achieved, without imposing an excessive burden."
#     },
#     {
#       "case": "Justice K.S. Puttaswamy (Retd.) and Another v. Union of India and Others, (2017) 10 SCC 1",
#       "citation": "(2017) 10 SCC 1",
#       "explanation": "Landmark judgment affirming the fundamental right to privacy under Article 21, which strongly supports the State's argument for regulating AI trained on 'sensitive public data' to protect individual privacy."
#     }
#   ],
#   "strategies": [
#     "If the petition is dismissed or partially dismissed, ABC Technologies should focus on full compliance with the Maharashtra Artificial Intelligence Regulation Act, 2024, including applying for the required licenses.",
#     "Engage with the State government and regulatory bodies through industry associations to advocate for the development of transparent, objective, and efficient licensing guidelines and processes.",
#     "Document any instances of actual opacity, delay, or political influence in the licensing process to potentially challenge specific administrative actions or decisions in the future.",
#     "Explore policy advocacy and public awareness campaigns to highlight the potential negative impact of overly restrictive or arbitrary regulations on innovation and competition within the AI sector."
#   ],
#   "penalties": [
#     "While the specific penalties under the newly passed Maharashtra Artificial Intelligence Regulation Act, 2024, are not detailed in the facts, typically, non-compliance with such licensing mandates can lead to:",
#     "Cessation of operations: Prohibition from operating AI models trained on sensitive public data within Maharashtra.",
#     "Monetary fines: Substantial financial penalties for operating without a valid license.",
#     "Legal prosecution: Potential for criminal charges against the company and its directors for deliberate non-compliance, depending on the severity and provisions of the Act.",
#     "Reputational damage: Adverse impact on the company's standing and ability to secure future contracts or investments."
#   ],
#   "finalAdvisory": "ABC Technologies faces an uphill battle in seeking a complete invalidation of the Maharashtra Artificial Intelligence Regulation Act, 2024. The State's legitimate concerns regarding privacy, misinformation, and public safety provide a strong basis for imposing 'reasonable restrictions' under Article 19(6) and regulatory measures. While the High Court may provide some relief by directing the State to introduce greater transparency and objectivity in the licensing process, based on the provided facts, a full 'win' (i.e., striking down the entire Act) is a low probability. It is crucial for ABC Technologies to gather concrete evidence of the alleged opacity and political influence to bolster its arguments. Irrespective of the immediate outcome, the company should prepare for compliance, actively engage in policy advocacy for clearer regulations, and carefully monitor any arbitrary implementation of the Act. Non-compliance could lead to significant operational disruptions, financial penalties, and reputational damage."
# }
# ```
# Generated answers.
# Request was processed in 28.95 seconds.
# INFO:     103.132.31.50:0 - "POST /caseoutcomeprediction HTTP/1.1" 200 OK
# New Request Received
# Raw Gemini response: ```json
# {
#   "title": "Legal Advisory to ABC Technologies Pvt. Ltd.",
#   "petitioner": "ABC Technologies Pvt. Ltd.",
#   "respondent": "State of Maharashtra",
#   "successProbability": "35%",
#   "likelyOutcome": "The Bombay High Court is likely to uphold the State of Maharashtra's legislative competence to regulate Artificial Intelligence models trained on sensitive public data, finding it to be a reasonable restriction under Article 19(6) and falling within the State's power to legislate for public order, safety, and privacy. However, the Court may scrutinize the specific provisions of the Maharashtra Artificial Intelligence Regulation Act, 2024, particularly concerning the licensing process. If ABC Technologies can convincingly demonstrate that the process is genuinely arbitrary, opaque, or disproportionate, the Court might direct the State to amend specific clauses to ensure transparency, objective criteria, and a fair hearing mechanism, rather than striking down the entire Act. The challenge under Article 301 is also likely to face similar scrutiny regarding reasonableness under Article 304(b).",
#   "strongPoints": [
#     "Challenge against the opacity and potential for political influence in the licensing process, which could violate Article 14 (equality before law) and principles of natural justice.",
#     "Argument that the restriction, if implemented arbitrarily, could be disproportionate and excessive, thereby not qualifying as a 'reasonable restriction' under Article 19(6).",
#     "Potential for the law to stifle innovation and competition if the licensing mechanism is not transparent, objective, and efficient."
#   ],
#   "weakPoints": [
#     "The State's argument regarding public safety, privacy, and prevention of misinformation from AI trained on sensitive public data constitutes a legitimate public interest, falling squarely within the ambit of 'reasonable restrictions' under Article 19(6).",
#     "Courts generally grant deference to legislative intent in regulating emerging technologies for public welfare, provided the law is not manifestly arbitrary or unconstitutional.",
#     "Establishing factual evidence of opacity, arbitrariness, or political influence in the licensing process will be crucial and challenging.",
#     "The challenge under Article 301 (freedom of trade, commerce, and intercourse) is also subject to 'reasonable restrictions' imposed by the State Legislature in the public interest under Article 304(b)."
#   ],
#   "legalPrecedents": [
#     {
#       "case": "Chintaman Rao v. State of Madhya Pradesh, AIR 1951 SC 118",
#       "explanation": "Established the principle that a restriction, to be reasonable under Article 19(6), must have a direct nexus with the object sought to be achieved and should not be excessive or arbitrary."
#     },
#     {
#       "case": "State of Madras v. V.G. Row, AIR 1952 SC 196",
#       "explanation": "Laid down the test for determining the reasonableness of a restriction, emphasizing that the test should be 'not in the abstract but in the context of the rights alleged to have been infringed, the object sought to be achieved, and the means employed'."
#     },
#     {
#       "case": "K.S. Puttaswamy v. Union of India, (2017) 10 SCC 1",
#       "explanation": "Recognized privacy as a fundamental right under Article 21, thereby strengthening the State's argument for regulating data-intensive technologies like AI to protect individual privacy."
#     },
#     {
#       "case": "Modern Dental College and Research Centre v. State of Madhya Pradesh, (2016) 7 SCC 353",
#       "explanation": "Reiterated the proportionality test for assessing the validity of restrictions on fundamental rights, requiring that the restriction must be necessary, have a legitimate aim, be suitable for achieving that aim, and be no more than is necessary."
#     },
#     {
#       "case": "Shreya Singhal v. Union of India, (2015) 5 SCC 1",
#       "explanation": "Dealt with restrictions on freedom of speech, but its principles on the vagueness of laws and the need for narrowly tailored restrictions are relevant to assessing the 'reasonableness' of the AI regulation."
#     }
#   ],
#   "strategies": [
#     "Prepare to comply with the Act's requirements, even if the legal challenge proceeds, to avoid penalties and business disruption.",
#     "Actively engage with the State government and regulatory authorities to provide input on the drafting of rules and guidelines for the licensing process, advocating for transparency and objective criteria.",
#     "If the Act is upheld, focus on challenging specific arbitrary decisions or actions taken under the licensing regime, rather than the constitutionality of the Act itself.",
#     "Explore developing AI models that do not rely on sensitive public data, or develop robust anonymization/pseudonymization techniques to mitigate compliance burdens."
#   ],
#   "penalties": [
#     "Fines and financial penalties for operating without a valid license or for non-compliance with the Act's provisions.",
#     "Cease and desist orders, leading to disruption or complete cessation of business operations involving non-compliant AI models.",
#     "Seizure of AI models, data, and infrastructure used in violation of the Act.",
#     "Reputational damage, loss of client trust, and difficulty in securing future contracts.",
#     "Potential criminal prosecution of company officials or directors if the Act provides for such penalties for severe or repeated violations."
#   ],
#   "finalAdvisory": "ABC Technologies faces an uphill battle in striking down the entire Maharashtra Artificial Intelligence Regulation Act, 2024. The State's power to regulate emerging technologies, especially when sensitive public data and public interest concerns like privacy and safety are involved, is robust under Indian law. The High Court is likely to uphold the State's legislative competence. ABC Technologies' strongest line of attack lies in challenging the *process* of licensing for arbitrariness, opacity, and lack of proportionality, rather than the fundamental power to regulate. It is advisable to gather concrete evidence demonstrating how the current licensing framework is practically unworkable, disproportionate, or susceptible to abuse. While pursuing the legal challenge, ABC Technologies should simultaneously prepare for compliance, seeking clarity and advocating for transparent and objective guidelines, as the most probable outcome is that the Act will be upheld, possibly with judicial directives for procedural improvements. Failure to comply could lead to significant financial penalties, operational disruption, and severe reputational damage."
# }
# ```
# Generated answers.
# Request was processed in 23.65 seconds.
# INFO:     103.132.31.50:0 - "POST /caseoutcomeprediction HTTP/1.1" 200 OK
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [206]
# INFO:     Stopping reloader process [36]
